# %% [markdown]
# # Github-topic-scraping-project
#
# ## Top Repositories for Github Topics

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import requests,urllib
import html5lib
import os

# %%
topics_url = 'https://www.github.com/topics'

# %%
response = requests.get(topics_url)

# %%
response.status_code
# More on Status Code
# Out:
# 200

# %%
# response.text  # display all the text of the html page
len(response.text) # total number of characters in the web page
# Out:
# 138972

# %%
pagecontent = response.text
print(pagecontent[:1000])
# Out:
# <!DOCTYPE html>
# <html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" >
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://github.githubassets.com">
#   <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#   <link rel="preconnect" href="https://github.githubassets.com" crossorigin>
#   <link rel="preconnect" href="https://avatars.githubusercontent.com">
#
#
#
#   <link crossorigin="anonymous" media="all" integrity="sha512-sD8zc/Dn1lguLc4FdbeVhD2gfxFCTXGr/y+MpJG3oX1vkAyaFf/7BHPtvv1dAHA0KG4bDEW3Ex1EPrzGTMtN2Q==" rel="stylesheet" href="https://github.githubassets.com/assets/light-b03f3373f0e7.css" /><link crossorigin="anonymous" media="all" integrity="sha512-V0872pNNqPTaPQFzdwX9tHIzJvB4F1Foi6VYDciZAMo/qHgBC8PvN2d/SkMweiNDbR6eF3cXcG0aPVrEtC8zqw==" rel="stylesheet" href="ht

# %% [markdown]
# ## Using Beautiful soup to parse and extract information

# %%
soup = BeautifulSoup(pagecontent,'html.parser')

# %%
soup
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
#soup.prettify

# %%
p = soup.find_all('p',attrs={
    'class':'f3 lh-condensed mb-0 mt-1 Link--primary'
    })
# print(p)
for item in p:
    print(item)
    print(item.text)
# Out:
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">3D</p>
# 3D
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Ajax</p>
# Ajax
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Algorithm</p>
# Algorithm
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Amp</p>
# Amp
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Android</p>
# Android
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Angular</p>
# Angular
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Ansible</p>
# Ansible
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">API</p>
# API
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Arduino</p>
# Arduino
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">ASP.NET</p>
# ASP.NET
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Atom</p>
# Atom
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Awesome Lists</p>
# Awesome Lists
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Amazon Web Services</p>
# Amazon Web Services
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Azure</p>
# Azure
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Babel</p>
# Babel
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Bash</p>
# Bash
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Bitcoin</p>
# Bitcoin
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Bootstrap</p>
# Bootstrap
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Bot</p>
# Bot
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">C</p>
# C
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Chrome</p>
# Chrome
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Chrome extension</p>
# Chrome extension
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Command line interface</p>
# Command line interface
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Clojure</p>
# Clojure
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Code quality</p>
# Code quality
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Code review</p>
# Code review
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Compiler</p>
# Compiler
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">Continuous integration</p>
# Continuous integration
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">COVID-19</p>
# COVID-19
# <p class="f3 lh-condensed mb-0 mt-1 Link--primary">C++</p>
# C++

# %%
topic_link_tag = soup.find_all('a',{'class' : 'no-underline flex-grow-0'})
len(topic_link_tag)
print(topic_link_tag)
# Out:
# [<a class="no-underline flex-grow-0" href="/topics/3d">
# <div class="color-bg-accent f4 color-fg-muted text-bold rounded mr-3 flex-shrink-0 text-center" style="width:64px; height:64px; line-height:64px;">
#             #
#           </div>
# </a>, <a class="no-underline flex-grow-0" href="/topics/ajax">
# <img alt="ajax" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/8be26d91eb231fec0b8856359979ac09f27173fd/topics/ajax/ajax.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/algorithm">
# <div class="color-bg-accent f4 color-fg-muted text-bold rounded mr-3 flex-shrink-0 text-center" style="width:64px; height:64px; line-height:64px;">
#             #
#           </div>
# </a>, <a class="no-underline flex-grow-0" href="/topics/amphp">
# <img alt="amphp" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/99fe59c0f4fb5d6545311440b4ce89a0d82b0804/topics/amphp/amphp.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/android">
# <img alt="android" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/80688e429a7d4ef2fca1e82350fe8e3517d3494d/topics/android/android.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/angular">
# <img alt="angular" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/80688e429a7d4ef2fca1e82350fe8e3517d3494d/topics/angular/angular.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/ansible">
# <img alt="ansible" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/80688e429a7d4ef2fca1e82350fe8e3517d3494d/topics/ansible/ansible.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/api">
# <div class="color-bg-accent f4 color-fg-muted text-bold rounded mr-3 flex-shrink-0 text-center" style="width:64px; height:64px; line-height:64px;">
#             #
#           </div>
# </a>, <a class="no-underline flex-grow-0" href="/topics/arduino">
# <img alt="arduino" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/80688e429a7d4ef2fca1e82350fe8e3517d3494d/topics/arduino/arduino.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/aspnet">
# <img alt="aspnet" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/80688e429a7d4ef2fca1e82350fe8e3517d3494d/topics/aspnet/aspnet.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/atom">
# <img alt="atom" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/80688e429a7d4ef2fca1e82350fe8e3517d3494d/topics/atom/atom.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/awesome">
# <img alt="awesome" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/80688e429a7d4ef2fca1e82350fe8e3517d3494d/topics/awesome/awesome.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/aws">
# <img alt="aws" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/fbceb94436312b6dacde68d122a5b9c7d11f9524/topics/aws/aws.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/azure">
# <img alt="azure" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/eaef8552d8b082ffafe2bfc8a5023d47da904aac/topics/azure/azure.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/babel">
# <img alt="babel" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/cb39e2385dfcec8a661d01bfacff6b1e33bbaa9d/topics/babel/babel.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/bash">
# <img alt="bash" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/80688e429a7d4ef2fca1e82350fe8e3517d3494d/topics/bash/bash.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/bitcoin">
# <img alt="bitcoin" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/80688e429a7d4ef2fca1e82350fe8e3517d3494d/topics/bitcoin/bitcoin.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/bootstrap">
# <img alt="bootstrap" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/80688e429a7d4ef2fca1e82350fe8e3517d3494d/topics/bootstrap/bootstrap.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/bot">
# <img alt="bot" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/0a84ca418425da147e4e43b1c74aa169d3265870/topics/bot/bot.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/c">
# <img alt="c" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/f3e22f0dca2be955676bc70d6214b95b13354ee8/topics/c/c.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/chrome">
# <img alt="chrome" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/80688e429a7d4ef2fca1e82350fe8e3517d3494d/topics/chrome/chrome.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/chrome-extension">
# <img alt="chrome-extension" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/80688e429a7d4ef2fca1e82350fe8e3517d3494d/topics/chrome-extension/chrome-extension.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/cli">
# <img alt="cli" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/aca0b3b69ca680013b925338b0cc428190aa42dc/topics/cli/cli.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/clojure">
# <img alt="clojure" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/80688e429a7d4ef2fca1e82350fe8e3517d3494d/topics/clojure/clojure.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/code-quality">
# <div class="color-bg-accent f4 color-fg-muted text-bold rounded mr-3 flex-shrink-0 text-center" style="width:64px; height:64px; line-height:64px;">
#             #
#           </div>
# </a>, <a class="no-underline flex-grow-0" href="/topics/code-review">
# <div class="color-bg-accent f4 color-fg-muted text-bold rounded mr-3 flex-shrink-0 text-center" style="width:64px; height:64px; line-height:64px;">
#             #
#           </div>
# </a>, <a class="no-underline flex-grow-0" href="/topics/compiler">
# <div class="color-bg-accent f4 color-fg-muted text-bold rounded mr-3 flex-shrink-0 text-center" style="width:64px; height:64px; line-height:64px;">
#             #
#           </div>
# </a>, <a class="no-underline flex-grow-0" href="/topics/continuous-integration">
# <div class="color-bg-accent f4 color-fg-muted text-bold rounded mr-3 flex-shrink-0 text-center" style="width:64px; height:64px; line-height:64px;">
#             #
#           </div>
# </a>, <a class="no-underline flex-grow-0" href="/topics/covid-19">
# <img alt="covid-19" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/af16e074f93c080d7b283815787283cab0e9414b/topics/covid-19/covid-19.png" width="64"/>
# </a>, <a class="no-underline flex-grow-0" href="/topics/cpp">
# <img alt="cpp" class="rounded mr-3" height="64" src="https://raw.githubusercontent.com/github/explore/180320cffc25f4ed1bbdfd33d4db3a66eeeeb358/topics/cpp/cpp.png" width="64"/>
# </a>]

# %%
topic0_url = "https://www.github.com"+topic_link_tag[0]['href']
topic0_url
# Out:
# 'https://www.github.com/topics/3d'

# %%
topic_title = []
for tag in p:
    topic_title.append(tag.text)
topic_title
# Out:
# ['3D',
#  'Ajax',
#  'Algorithm',
#  'Amp',
#  'Android',
#  'Angular',
#  'Ansible',
#  'API',
#  'Arduino',
#  'ASP.NET',
#  'Atom',
#  'Awesome Lists',
#  'Amazon Web Services',
#  'Azure',
#  'Babel',
#  'Bash',
#  'Bitcoin',
#  'Bootstrap',
#  'Bot',
#  'C',
#  'Chrome',
#  'Chrome extension',
#  'Command line interface',
#  'Clojure',
#  'Code quality',
#  'Code review',
#  'Compiler',
#  'Continuous integration',
#  'COVID-19',
#  'C++']

# %%
topic_desc_tag = soup.find_all('p', attrs={'class':'f5 color-fg-muted mb-0 mt-1'})

# %%
topic_desc_tag
# Out:
# [<p class="f5 color-fg-muted mb-0 mt-1">
#            3D modeling is the process of virtually developing the surface and structure of a 3D object.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Ajax is a technique for creating interactive web applications.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Algorithms are self-contained sequences that carry out a variety of tasks.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Amp is a non-blocking concurrency library for PHP.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Android is an operating system built by Google designed for mobile devices.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Angular is an open source web application platform.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Ansible is a simple and powerful automation engine.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            An API (Application Programming Interface) is a collection of protocols and subroutines for building software.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Arduino is an open source hardware and software company and maker community.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            ASP.NET is a web framework for building modern web apps and services.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Atom is a open source text editor built with web technologies.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            An awesome list is a list of awesome things curated by the community.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Amazon Web Services provides on-demand cloud computing platforms on a subscription basis.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Azure is a cloud computing service created by Microsoft.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Babel is a compiler for writing next generation JavaScript, today.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Bash is a shell and command language interpreter for the GNU operating system.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Bitcoin is a cryptocurrency developed by Satoshi Nakamoto.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Bootstrap is an HTML, CSS, and JavaScript framework.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            A bot is an application that runs automated tasks over the Internet.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            C is a general purpose programming language that first appeared in 1972.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Chrome is a web browser from the tech company Google.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Google Chrome Extensions are add-ons that allow users to customize their Chrome web browser.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            A CLI, or command-line interface, is a console that helps users issue commands to a program.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Clojure is a dynamic, general-purpose programming language.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Automate your code review with style, quality, security, and test‑coverage checks when you need them.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Ensure your code meets quality standards and ship with confidence.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Compilers are software that translate higher-level programming languages to lower-level languages (e.g. machine code).
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            Automatically build and test your code as you push it upstream, preventing bugs from being deployed to production.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            The coronavirus disease 2019 (COVID-19) is an infectious disease caused by SARS-CoV-2.
#          </p>,
#  <p class="f5 color-fg-muted mb-0 mt-1">
#            C++ is a general purpose and object-oriented programming language.
#          </p>]

# %%
topic_descriptions = []

for tag in topic_desc_tag:
    topic_descriptions.append(tag.text.strip())
    
print(topic_descriptions)
# Out:
# ['3D modeling is the process of virtually developing the surface and structure of a 3D object.', 'Ajax is a technique for creating interactive web applications.', 'Algorithms are self-contained sequences that carry out a variety of tasks.', 'Amp is a non-blocking concurrency library for PHP.', 'Android is an operating system built by Google designed for mobile devices.', 'Angular is an open source web application platform.', 'Ansible is a simple and powerful automation engine.', 'An API (Application Programming Interface) is a collection of protocols and subroutines for building software.', 'Arduino is an open source hardware and software company and maker community.', 'ASP.NET is a web framework for building modern web apps and services.', 'Atom is a open source text editor built with web technologies.', 'An awesome list is a list of awesome things curated by the community.', 'Amazon Web Services provides on-demand cloud computing platforms on a subscription basis.', 'Azure is a cloud computing service created by Microsoft.', 'Babel is a compiler for writing next generation JavaScript, today.', 'Bash is a shell and command language interpreter for the GNU operating system.', 'Bitcoin is a cryptocurrency developed by Satoshi Nakamoto.', 'Bootstrap is an HTML, CSS, and JavaScript framework.', 'A bot is an application that runs automated tasks over the Internet.', 'C is a general purpose programming language that first appeared in 1972.', 'Chrome is a web browser from the tech company Google.', 'Google Chrome Extensions are add-ons that allow users to customize their Chrome web browser.', 'A CLI, or command-line interface, is a console that helps users issue commands to a program.', 'Clojure is a dynamic, general-purpose programming language.', 'Automate your code review with style, quality, security, and test‑coverage checks when you need them.', 'Ensure your code meets quality standards and ship with confidence.', 'Compilers are software that translate higher-level programming languages to lower-level languages (e.g. machine code).', 'Automatically build and test your code as you push it upstream, preventing bugs from being deployed to production.', 'The coronavirus disease 2019 (COVID-19) is an infectious disease caused by SARS-CoV-2.', 'C++ is a general purpose and object-oriented programming language.']

# %%
topic_urls = []
base = "https://www.github.com"
for tag in topic_link_tag:
    topic_urls.append(base+tag['href'])
topic_urls
# Out:
# ['https://www.github.com/topics/3d',
#  'https://www.github.com/topics/ajax',
#  'https://www.github.com/topics/algorithm',
#  'https://www.github.com/topics/amphp',
#  'https://www.github.com/topics/android',
#  'https://www.github.com/topics/angular',
#  'https://www.github.com/topics/ansible',
#  'https://www.github.com/topics/api',
#  'https://www.github.com/topics/arduino',
#  'https://www.github.com/topics/aspnet',
#  'https://www.github.com/topics/atom',
#  'https://www.github.com/topics/awesome',
#  'https://www.github.com/topics/aws',
#  'https://www.github.com/topics/azure',
#  'https://www.github.com/topics/babel',
#  'https://www.github.com/topics/bash',
#  'https://www.github.com/topics/bitcoin',
#  'https://www.github.com/topics/bootstrap',
#  'https://www.github.com/topics/bot',
#  'https://www.github.com/topics/c',
#  'https://www.github.com/topics/chrome',
#  'https://www.github.com/topics/chrome-extension',
#  'https://www.github.com/topics/cli',
#  'https://www.github.com/topics/clojure',
#  'https://www.github.com/topics/code-quality',
#  'https://www.github.com/topics/code-review',
#  'https://www.github.com/topics/compiler',
#  'https://www.github.com/topics/continuous-integration',
#  'https://www.github.com/topics/covid-19',
#  'https://www.github.com/topics/cpp']

# %% [markdown]
# ## creating a csv file of the scraped data using pandas dataframe

# %%
topic_dict = {
    'Title': topic_title,
    'Description' : topic_descriptions,
    'Url' : topic_urls
}
topic_df = pd.DataFrame(topic_dict)
topic_df
# Out:
#                      Title                                        Description  \
# 0                       3D  3D modeling is the process of virtually develo...
# 1                     Ajax  Ajax is a technique for creating interactive w...
# 2                Algorithm  Algorithms are self-contained sequences that c...
# 3                      Amp  Amp is a non-blocking concurrency library for ...
# 4                  Android  Android is an operating system built by Google...
# 5                  Angular  Angular is an open source web application plat...
# 6                  Ansible  Ansible is a simple and powerful automation en...
# 7                      API  An API (Application Programming Interface) is ...
# 8                  Arduino  Arduino is an open source hardware and softwar...
# 9                  ASP.NET  ASP.NET is a web framework for building modern...
# 10                    Atom  Atom is a open source text editor built with w...
# 11           Awesome Lists  An awesome list is a list of awesome things cu...
# 12     Amazon Web Services  Amazon Web Services provides on-demand cloud c...
# 13                   Azure  Azure is a cloud computing service created by ...
# 14                   Babel  Babel is a compiler for writing next generatio...
# 15                    Bash  Bash is a shell and command language interpret...
# 16                 Bitcoin  Bitcoin is a cryptocurrency developed by Satos...
# 17               Bootstrap  Bootstrap is an HTML, CSS, and JavaScript fram...
# 18                     Bot  A bot is an application that runs automated ta...
# 19                       C  C is a general purpose programming language th...
# 20                  Chrome  Chrome is a web browser from the tech company ...
# 21        Chrome extension  Google Chrome Extensions are add-ons that allo...
# 22  Command line interface  A CLI, or command-line interface, is a console...
# 23                 Clojure  Clojure is a dynamic, general-purpose programm...
# 24            Code quality  Automate your code review with style, quality,...
# 25             Code review  Ensure your code meets quality standards and s...
# 26                Compiler  Compilers are software that translate higher-l...
# 27  Continuous integration  Automatically build and test your code as you ...
# 28                COVID-19  The coronavirus disease 2019 (COVID-19) is an ...
# 29                     C++  C++ is a general purpose and object-oriented p...
#
#                                                   Url
# 0                    https://www.github.com/topics/3d
# 1                  https://www.github.com/topics/ajax
# 2             https://www.github.com/topics/algorithm
# 3                 https://www.github.com/topics/amphp
# 4               https://www.github.com/topics/android
# 5               https://www.github.com/topics/angular
# 6               https://www.github.com/topics/ansible
# 7                   https://www.github.com/topics/api
# 8               https://www.github.com/topics/arduino
# 9                https://www.github.com/topics/aspnet
# 10                 https://www.github.com/topics/atom
# 11              https://www.github.com/topics/awesome
# 12                  https://www.github.com/topics/aws
# 13                https://www.github.com/topics/azure
# 14                https://www.github.com/topics/babel
# 15                 https://www.github.com/topics/bash
# 16              https://www.github.com/topics/bitcoin
# 17            https://www.github.com/topics/bootstrap
# 18                  https://www.github.com/topics/bot
# 19                    https://www.github.com/topics/c
# 20               https://www.github.com/topics/chrome
# 21     https://www.github.com/topics/chrome-extension
# 22                  https://www.github.com/topics/cli
# 23              https://www.github.com/topics/clojure
# 24         https://www.github.com/topics/code-quality
# 25          https://www.github.com/topics/code-review
# 26             https://www.github.com/topics/compiler
# 27  https://www.github.com/topics/continuous-integ...
# 28             https://www.github.com/topics/covid-19
# 29                  https://www.github.com/topics/cpp

# %%
topic_df.to_csv('Github_Topics.csv')

# %% [markdown]
# ## getting information out of a topic page url

# %%
url1 = topic_urls[0]
url1
# Out:
# 'https://www.github.com/topics/3d'

# %%
response = requests.get(url1)

# %%
response.status_code
# Out:
# 200

# %%
len(response.text)
# Out:
# 624707

# %%
soup2 = BeautifulSoup(response.text,'html.parser')
# soup2

# %%
repo_tags = soup2.find_all('h3',attrs={
    'class' : 'f3 color-fg-muted text-normal lh-condensed'})
len(repo_tags)
# Out:
# 30

# %%
a_tag = repo_tags[0].find_all('a')
# a_tag[0].text.strip()
a_tag
# Out:
# [<a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":97088,"originating_url":"https://github.com/topics/3d","user_id":null}}' data-hydro-click-hmac="4bdbc49d3c05ae7f70b531fbce709a384200b0768554e0172950286a8db30940" data-view-component="true" href="/mrdoob">
#              mrdoob
#  </a>,
#  <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":576201,"originating_url":"https://github.com/topics/3d","user_id":null}}' data-hydro-click-hmac="517d3d5cb9d89752156923904a4238816bc9b51ab7772f3e3644ce897d8dd4e5" data-view-component="true" href="/mrdoob/three.js">
#              three.js
#  </a>]

# %%
a_tag[1].text.strip()
# Out:
# 'three.js'

# %%
repo_url = a_tag[1]['href']
repo_link1 = base + repo_url
repo_link1
# Out:
# 'https://www.github.com/mrdoob/three.js'

# %%
stars= soup2.find_all('span',attrs= {
    'class' : 'Counter js-social-count'
})
stars
# Out:
# [<span aria-label="80217 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="80,217">80.2k</span>,
#  <span aria-label="19755 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="19,755">19.8k</span>,
#  <span aria-label="17192 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="17,192">17.2k</span>,
#  <span aria-label="16140 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="16,140">16.1k</span>,
#  <span aria-label="13929 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="13,929">13.9k</span>,
#  <span aria-label="13009 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="13,009">13k</span>,
#  <span aria-label="12448 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="12,448">12.4k</span>,
#  <span aria-label="10914 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="10,914">10.9k</span>,
#  <span aria-label="9056 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="9,056">9.1k</span>,
#  <span aria-label="8404 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="8,404">8.4k</span>,
#  <span aria-label="7719 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="7,719">7.7k</span>,
#  <span aria-label="7080 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="7,080">7.1k</span>,
#  <span aria-label="6365 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="6,365">6.4k</span>,
#  <span aria-label="5070 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="5,070">5.1k</span>,
#  <span aria-label="4940 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="4,940">4.9k</span>,
#  <span aria-label="4781 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="4,781">4.8k</span>,
#  <span aria-label="4680 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="4,680">4.7k</span>,
#  <span aria-label="4592 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="4,592">4.6k</span>,
#  <span aria-label="4578 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="4,578">4.6k</span>,
#  <span aria-label="4560 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="4,560">4.6k</span>,
#  <span aria-label="4408 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="4,408">4.4k</span>,
#  <span aria-label="4098 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="4,098">4.1k</span>,
#  <span aria-label="4086 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="4,086">4.1k</span>,
#  <span aria-label="3848 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="3,848">3.8k</span>,
#  <span aria-label="3506 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="3,506">3.5k</span>,
#  <span aria-label="3500 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="3,500">3.5k</span>,
#  <span aria-label="3266 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="3,266">3.3k</span>,
#  <span aria-label="3207 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="3,207">3.2k</span>,
#  <span aria-label="3140 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="3,140">3.1k</span>,
#  <span aria-label="2810 users starred this repository" class="Counter js-social-count" data-pjax-replace="true" data-plural-suffix="users starred this repository" data-singular-suffix="user starred this repository" data-view-component="true" id="repo-stars-counter-star" title="2,810">2.8k</span>]

# %%
star_repo1 = stars[0].text
star_repo1
# Out:
# '80.2k'

# %%
def parse_star_count(star_str):
    star_str = star_str.strip()
    if star_str[-1] == 'k':
        return int(float(star_str[:-1])*1000)
    return int(stars_str)

# %%
star_repo1 = stars[0].text
parse_star_count(star_repo1)
# Out:
# 80200

# %%
def get_repo_info(h3_tag,star_tag):
    atags = h3_tag.find_all('a')
    username = atags[0].text.strip()
    reponame = atags[1].text.strip()
    repo_url = "https://www.github.com"+ atags[1]['href']
    stars = parse_star_count(star_tag.text.strip())
    
    return username,reponame,repo_url,stars

# %%
star_repo1
# Out:
# '80.2k'

# %%
get_repo_info(repo_tags[0],stars[0])
# Out:
# ('mrdoob', 'three.js', 'https://www.github.com/mrdoob/three.js', 80200)

# %%
topic_repo_dict = {
    'Username':[],
    'Repo_Name':[],
    'Repo_Url':[],
    'Stars': []
}
print(repo_tags)
for i in range(len(repo_tags)):
    repo_info = get_repo_info(repo_tags[i],stars[i])
    print(repo_info)
    topic_repo_dict['Username'].append(repo_info[0])
    topic_repo_dict['Repo_Name'].append(repo_info[1])
    topic_repo_dict['Repo_Url'].append(repo_info[2])
    topic_repo_dict['Stars'].append(repo_info[3])
# Out:
# [<h3 class="f3 color-fg-muted text-normal lh-condensed">
# <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":97088,"originating_url":"https://github.com/topics/3d","user_id":null}}' data-hydro-click-hmac="4bdbc49d3c05ae7f70b531fbce709a384200b0768554e0172950286a8db30940" data-view-component="true" href="/mrdoob">
#             mrdoob
# </a>          /
#           <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":576201,"originating_url":"https://github.com/topics/3d","user_id":null}}' data-hydro-click-hmac="517d3d5cb9d89752156923904a4238816bc9b51ab7772f3e3644ce897d8dd4e5" data-view-component="true" href="/mrdoob/three.js">
#             three.js
# </a> </h3>, <h3 class="f3 color-fg-muted text-normal lh-condensed">
# <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":509841,"originating_url":"https://github.com/topics/3d","user_id":null}}' data-hydro-click-hmac="760dcd7b253cb1a27d9b1a8675e86db885295be4e0d8d9fa7397adf923075d36" data-view-component="true" href="/libgdx">
#             libgdx
# </a>          /
#           <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":5373551,"originating_url":"https://github.com/topics/3d","user_id":null}}' data-hydro-click-hmac="ff9d8fbd4b6a268d54aa44ebd06922a789e146ae9d21db01b8ba7839646f5507" data-view-component="true" href="/libgdx/libgdx">
#             libgdx
# </a> </h3>, <h3 class="f3 color-fg-muted text-normal lh-condensed">
# <a data-ga-click="Explore, go to repository owner, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"OWNER","click_visual_representation":"REPOSITORY_OWNER_HEADING","actor_id":null,"record_id":45790596,"originating_url":"https://github.com/topics/3d","user_id":null}}' data-hydro-click-hmac="14658fab6217ec4ba70f16dd98006d4334793fae49cc25ce2e1c0bb5a8950006" data-view-component="true" href="/pmndrs">
#             pmndrs
# </a>          /
#           <a class="text-bold wb-break-word" data-ga-click="Explore, go to repository, location:explore feed" data-hydro-click='{"event_type":"explore.click","payload":{"click_context":"REPOSITORY_CARD","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id
"originating_url":"https://github.com/topics/3d","user_id":null}}' data-hydro-click-hmac="320bb87cd817c0d9e2c5e7348ea510c86f4f598db413ac2e151404ee7b47cd90" data-view-component="true" href="/cnr-isti-vclab/meshlab">
#             meshlab
# </a> </h3>]
# ('mrdoob', 'three.js', 'https://www.github.com/mrdoob/three.js', 80200)
# ('libgdx', 'libgdx', 'https://www.github.com/libgdx/libgdx', 19800)
# ('pmndrs', 'react-three-fiber', 'https://www.github.com/pmndrs/react-three-fiber', 17200)
# ('BabylonJS', 'Babylon.js', 'https://www.github.com/BabylonJS/Babylon.js', 16100)
# ('aframevr', 'aframe', 'https://www.github.com/aframevr/aframe', 13900)
# ('ssloy', 'tinyrenderer', 'https://www.github.com/ssloy/tinyrenderer', 13000)
# ('lettier', '3d-game-shaders-for-beginners', 'https://www.github.com/lettier/3d-game-shaders-for-beginners', 12400)
# ('FreeCAD', 'FreeCAD', 'https://www.github.com/FreeCAD/FreeCAD', 10900)
# ('metafizzy', 'zdog', 'https://www.github.com/metafizzy/zdog', 9100)
# ('CesiumGS', 'cesium', 'https://www.github.com/CesiumGS/cesium', 8400)
# ('timzhang642', '3D-Machine-Learning', 'https://www.github.com/timzhang642/3D-Machine-Learning', 7700)
# ('a1studmuffin', 'SpaceshipGenerator', 'https://www.github.com/a1studmuffin/SpaceshipGenerator', 7100)
# ('isl-org', 'Open3D', 'https://www.github.com/isl-org/Open3D', 6400)
# ('blender', 'blender', 'https://www.github.com/blender/blender', 5100)
# ('domlysz', 'BlenderGIS', 'https://www.github.com/domlysz/BlenderGIS', 4900)
# ('spritejs', 'spritejs', 'https://www.github.com/spritejs/spritejs', 4800)
# ('openscad', 'openscad', 'https://www.github.com/openscad/openscad', 4700)
# ('tensorspace-team', 'tensorspace', 'https://www.github.com/tensorspace-team/tensorspace', 4600)
# ('jagenjo', 'webglstudio.js', 'https://www.github.com/jagenjo/webglstudio.js', 4600)
# ('YadiraF', 'PRNet', 'https://www.github.com/YadiraF/PRNet', 4600)
# ('AaronJackson', 'vrn', 'https://www.github.com/AaronJackson/vrn', 4400)
# ('ssloy', 'tinyraytracer', 'https://www.github.com/ssloy/tinyraytracer', 4100)
# ('google', 'model-viewer', 'https://www.github.com/google/model-viewer', 4100)
# ('mosra', 'magnum', 'https://www.github.com/mosra/magnum', 3800)
# ('gfxfundamentals', 'webgl-fundamentals', 'https://www.github.com/gfxfundamentals/webgl-fundamentals', 3500)
# ('FyroxEngine', 'Fyrox', 'https://www.github.com/FyroxEngine/Fyrox', 3500)
# ('tengbao', 'vanta', 'https://www.github.com/tengbao/vanta', 3300)
# ('cleardusk', '3DDFA', 'https://www.github.com/cleardusk/3DDFA', 3200)
# ('jasonlong', 'isometric-contributions', 'https://www.github.com/jasonlong/isometric-contributions', 3100)
# ('cnr-isti-vclab', 'meshlab', 'https://www.github.com/cnr-isti-vclab/meshlab', 2800)

# %%
topic_repo_dict
# Out:
# {'Username': ['mrdoob',
#   'libgdx',
#   'pmndrs',
#   'BabylonJS',
#   'aframevr',
#   'ssloy',
#   'lettier',
#   'FreeCAD',
#   'metafizzy',
#   'CesiumGS',
#   'timzhang642',
#   'a1studmuffin',
#   'isl-org',
#   'blender',
#   'domlysz',
#   'spritejs',
#   'openscad',
#   'tensorspace-team',
#   'jagenjo',
#   'YadiraF',
#   'AaronJackson',
#   'ssloy',
#   'google',
#   'mosra',
#   'gfxfundamentals',
#   'FyroxEngine',
#   'tengbao',
#   'cleardusk',
#   'jasonlong',
#   'cnr-isti-vclab'],
#  'Repo_Name': ['three.js',
#   'libgdx',
#   'react-three-fiber',
#   'Babylon.js',
#   'aframe',
#   'tinyrenderer',
#   '3d-game-shaders-for-beginners',
#   'FreeCAD',
#   'zdog',
#   'cesium',
#   '3D-Machine-Learning',
#   'SpaceshipGenerator',
#   'Open3D',
#   'blender',
#   'BlenderGIS',
#   'spritejs',
#   'openscad',
#   'tensorspace',
#   'webglstudio.js',
#   'PRNet',
#   'vrn',
#   'tinyraytracer',
#   'model-viewer',
#   'magnum',
#   'webgl-fundamentals',
#   'Fyrox',
#   'vanta',
#   '3DDFA',
#   'isometric-contributions',
#   'meshlab'],
#  'Repo_Url': ['https://www.github.com/mrdoob/three.js',
#   'https://www.github.com/libgdx/libgdx',
#   'https://www.github.com/pmndrs/react-three-fiber',
#   'https://www.github.com/BabylonJS/Babylon.js',
#   'https://www.github.com/aframevr/aframe',
#   'https://www.github.com/ssloy/tinyrenderer',
#   'https://www.github.com/lettier/3d-game-shaders-for-beginners',
#   'https://www.github.com/FreeCAD/FreeCAD',
#   'https://www.github.com/metafizzy/zdog',
#   'https://www.github.com/CesiumGS/cesium',
#   'https://www.github.com/timzhang642/3D-Machine-Learning',
#   'https://www.github.com/a1studmuffin/SpaceshipGenerator',
#   'https://www.github.com/isl-org/Open3D',
#   'https://www.github.com/blender/blender',
#   'https://www.github.com/domlysz/BlenderGIS',
#   'https://www.github.com/spritejs/spritejs',
#   'https://www.github.com/openscad/openscad',
#   'https://www.github.com/tensorspace-team/tensorspace',
#   'https://www.github.com/jagenjo/webglstudio.js',
#   'https://www.github.com/YadiraF/PRNet',
#   'https://www.github.com/AaronJackson/vrn',
#   'https://www.github.com/ssloy/tinyraytracer',
#   'https://www.github.com/google/model-viewer',
#   'https://www.github.com/mosra/magnum',
#   'https://www.github.com/gfxfundamentals/webgl-fundamentals',
#   'https://www.github.com/FyroxEngine/Fyrox',
#   'https://www.github.com/tengbao/vanta',
#   'https://www.github.com/cleardusk/3DDFA',
#   'https://www.github.com/jasonlong/isometric-contributions',
#   'https://www.github.com/cnr-isti-vclab/meshlab'],
#  'Stars': [80200,
#   19800,
#   17200,
#   16100,
#   13900,
#   13000,
#   12400,
#   10900,
#   9100,
#   8400,
#   7700,
#   7100,
#   6400,
#   5100,
#   4900,
#   4800,
#   4700,
#   4600,
#   4600,
#   4600,
#   4400,
#   4100,
#   4100,
#   3800,
#   3500,
#   3500,
#   3300,
#   3200,
#   3100,
#   2800]}

# %%
def get_topic_page(topic_url):
    response = requests.get(topic_url)
    if response.status_code !=200:
        raise Exception('Failed to load page {}'.format(topic_url))
    topic_doc = BeautifulSoup(response.text,'html.parser')
    return topic_doc 
    
def get_topic_repos(topic_doc):
    
    repo_tags = topic_doc.find_all('h3',attrs={
        'class' : 'f3 color-fg-muted text-normal lh-condensed'})
    stars_tags= soup2.find_all('span',attrs= {
        'class' : 'Counter js-social-count'
            })
    topic_repo_dicts = {
    'Username':[],
    'Repo_Name':[],
    'Repo_Url':[],
    'Stars': []
    }
    for i in range(len(repo_tags)):
        repo_info = get_repo_info(repo_tags[i],stars_tags[i])
#         print(repo_info)
        topic_repo_dicts['Username'].append(repo_info[0])
        topic_repo_dicts['Repo_Name'].append(repo_info[1])
        topic_repo_dicts['Repo_Url'].append(repo_info[2])
        topic_repo_dicts['Stars'].append(repo_info[3])
        
    return pd.DataFrame(topic_repo_dicts)


def get_repo_info(h3_tag,star_tag):
    atags = h3_tag.find_all('a')
    username = atags[0].text.strip()
    reponame = atags[1].text.strip()
    repo_url = "https://www.github.com"+ atags[1]['href']
    stars = parse_star_count(star_tag.text.strip())
    
    return username,reponame,repo_url,stars

def scrape_topic(topic_url,topic_name):
    filename = topic_name+".csv"
    if os.path.exists(filename):
        print(f"File {filename} already exists. Skipping...")
        return 
    topic_df = get_topic_repos(get_topic_page(topic_url))
    
    topic_df.to_csv(filename,index = None)

# %%
topic_urls[4]
# Out:
# 'https://www.github.com/topics/android'

# %%
#
get_topic_repos(get_topic_page(topic_urls[6]))#.to_csv('ansible.csv0',index = None)
# Out:
#              Username                     Repo_Name  \
# 0             ansible                       ansible
# 1         trailofbits                          algo
# 2     StreisandEffect                     streisand
# 3        bregman-arie              devops-exercises
# 4     kubernetes-sigs                     kubespray
# 5             ansible                           awx
# 6             easzlab                       kubeasz
# 7         geerlingguy            ansible-for-devops
# 8            khuedoan                       homelab
# 9   ansible-semaphore                     semaphore
# 10            rundeck                       rundeck
# 11        geerlingguy              mac-dev-playbook
# 12            Tikam02                  DevOps-Guide
# 13       KubeOperator                  KubeOperator
# 14        MichaelCade                90DaysOfDevOps
# 15              clong                  DetectionLab
# 16  ansible-community                      molecule
# 17      opendevops-cn                    opendevops
# 18               werf                          werf
# 19         netbootxyz                   netboot.xyz
# 20         welliamcao                     OpsManage
# 21  ansible-community                  ansible-lint
# 22            dev-sec  ansible-collection-hardening
# 23           alixaxel             chrome-aws-lambda
# 24        litmuschaos                        litmus
# 25              roots                       trellis
# 26         ansistrano                        deploy
# 27          openshift             openshift-ansible
# 28           fboender                  ansible-cmdb
# 29         pytest-dev              pytest-testinfra
#
#                                              Repo_Url  Stars
# 0              https://www.github.com/ansible/ansible  80200
# 1             https://www.github.com/trailofbits/algo  19800
# 2    https://www.github.com/StreisandEffect/streisand  17200
# 3   https://www.github.com/bregman-arie/devops-exe...  16100
# 4    https://www.github.com/kubernetes-sigs/kubespray  13900
# 5                  https://www.github.com/ansible/awx  13000
# 6              https://www.github.com/easzlab/kubeasz  12400
# 7   https://www.github.com/geerlingguy/ansible-for...  10900
# 8             https://www.github.com/khuedoan/homelab   9100
# 9   https://www.github.com/ansible-semaphore/semap...   8400
# 10             https://www.github.com/rundeck/rundeck   7700
# 11  https://www.github.com/geerlingguy/mac-dev-pla...   7100
# 12        https://www.github.com/Tikam02/DevOps-Guide   6400
# 13   https://www.github.com/KubeOperator/KubeOperator   5100
# 14  https://www.github.com/MichaelCade/90DaysOfDevOps   4900
# 15          https://www.github.com/clong/DetectionLab   4800
# 16  https://www.github.com/ansible-community/molecule   4700
# 17    https://www.github.com/opendevops-cn/opendevops   4600
# 18                   https://www.github.com/werf/werf   4600
# 19      https://www.github.com/netbootxyz/netboot.xyz   4600
# 20        https://www.github.com/welliamcao/OpsManage   4400
# 21  https://www.github.com/ansible-community/ansib...   4100
# 22  https://www.github.com/dev-sec/ansible-collect...   4100
# 23  https://www.github.com/alixaxel/chrome-aws-lambda   3800
# 24          https://www.github.com/litmuschaos/litmus   3500
# 25               https://www.github.com/roots/trellis   3500
# 26           https://www.github.com/ansistrano/deploy   3300
# 27  https://www.github.com/openshift/openshift-ans...   3200
# 28       https://www.github.com/fboender/ansible-cmdb   3100
# 29  https://www.github.com/pytest-dev/pytest-testi...   2800

# %%
def get_topic_titles(soup):
    topic_title_tags = soup.find_all('p',attrs={
    'class':'f3 lh-condensed mb-0 mt-1 Link--primary'
    })
    topic_link_tag = soup.find_all('a',{'class' : 'no-underline flex-grow-0'})
    topic_titles = []
    
    for tag in topic_title_tags:
        topic_titles.append(tag.text)
    return topic_titles

def get_topic_description(soup):
    topic_desc_tag = soup.find_all('p', attrs=
                                   {'class':'f5 color-fg-muted mb-0 mt-1'})
    topic_descriptions = []

    for tag in topic_desc_tag:
        topic_descriptions.append(tag.text.strip())
    return topic_descriptions

def get_topic_urls(soup):
    topic_title_tags = soup.find_all('p',attrs={
    'class':'f3 lh-condensed mb-0 mt-1 Link--primary'
    })
    topic_urls = []
    base = "https://www.github.com"
    for tag in topic_link_tags:
        topic_urls.append(base+tag['href'])
    return topic_urls

def scrape_topics():
    topics_url = "https://github.com/topics"
    requests.get(topics_url)
    if response.status_code !=200:
        raise Exception('Failed to load page {}'.format(topic_url))    
    topics_dict = {
        'title' : get_topic_titles(soup),
        'decscription': get_topic_description(soup),
        'url':get_topic_urls(soup)
    }
    return pd.DataFrame(topics_dict)

# %%
## Collectings

# topic_title_tags = soup.find_all('p',attrs={
#     'class':'f3 lh-condensed mb-0 mt-1 Link--primary'
#     })


# topic_desc_tag = soup.find_all('p', attrs={'class':'f5 color-fg-muted mb-0 mt-1'})

# topic_link_tags = soup.find_all('a',{'class' : 'no-underline flex-grow-0'})

# topic_title = []
# for tag in p:
#     topic_title.append(tag.text)
# topic_title

# topic_descriptions = []

# for tag in topic_desc_tag:
#     topic_descriptions.append(tag.text.strip())
    
# print(topic_descriptions)

# topic_urls = []
# base = "https://www.github.com"
# for tag in topic_link_tag:
#     topic_urls.append(base+tag['href'])
# topic_urls

# %%
scrape_topics()
# Out:
#                      title                                       decscription  \
# 0                       3D  3D modeling is the process of virtually develo...
# 1                     Ajax  Ajax is a technique for creating interactive w...
# 2                Algorithm  Algorithms are self-contained sequences that c...
# 3                      Amp  Amp is a non-blocking concurrency library for ...
# 4                  Android  Android is an operating system built by Google...
# 5                  Angular  Angular is an open source web application plat...
# 6                  Ansible  Ansible is a simple and powerful automation en...
# 7                      API  An API (Application Programming Interface) is ...
# 8                  Arduino  Arduino is an open source hardware and softwar...
# 9                  ASP.NET  ASP.NET is a web framework for building modern...
# 10                    Atom  Atom is a open source text editor built with w...
# 11           Awesome Lists  An awesome list is a list of awesome things cu...
# 12     Amazon Web Services  Amazon Web Services provides on-demand cloud c...
# 13                   Azure  Azure is a cloud computing service created by ...
# 14                   Babel  Babel is a compiler for writing next generatio...
# 15                    Bash  Bash is a shell and command language interpret...
# 16                 Bitcoin  Bitcoin is a cryptocurrency developed by Satos...
# 17               Bootstrap  Bootstrap is an HTML, CSS, and JavaScript fram...
# 18                     Bot  A bot is an application that runs automated ta...
# 19                       C  C is a general purpose programming language th...
# 20                  Chrome  Chrome is a web browser from the tech company ...
# 21        Chrome extension  Google Chrome Extensions are add-ons that allo...
# 22  Command line interface  A CLI, or command-line interface, is a console...
# 23                 Clojure  Clojure is a dynamic, general-purpose programm...
# 24            Code quality  Automate your code review with style, quality,...
# 25             Code review  Ensure your code meets quality standards and s...
# 26                Compiler  Compilers are software that translate higher-l...
# 27  Continuous integration  Automatically build and test your code as you ...
# 28                COVID-19  The coronavirus disease 2019 (COVID-19) is an ...
# 29                     C++  C++ is a general purpose and object-oriented p...
#
#                                                   url
# 0                    https://www.github.com/topics/3d
# 1                  https://www.github.com/topics/ajax
# 2             https://www.github.com/topics/algorithm
# 3                 https://www.github.com/topics/amphp
# 4               https://www.github.com/topics/android
# 5               https://www.github.com/topics/angular
# 6               https://www.github.com/topics/ansible
# 7                   https://www.github.com/topics/api
# 8               https://www.github.com/topics/arduino
# 9                https://www.github.com/topics/aspnet
# 10                 https://www.github.com/topics/atom
# 11              https://www.github.com/topics/awesome
# 12                  https://www.github.com/topics/aws
# 13                https://www.github.com/topics/azure
# 14                https://www.github.com/topics/babel
# 15                 https://www.github.com/topics/bash
# 16              https://www.github.com/topics/bitcoin
# 17            https://www.github.com/topics/bootstrap
# 18                  https://www.github.com/topics/bot
# 19                    https://www.github.com/topics/c
# 20               https://www.github.com/topics/chrome
# 21     https://www.github.com/topics/chrome-extension
# 22                  https://www.github.com/topics/cli
# 23              https://www.github.com/topics/clojure
# 24         https://www.github.com/topics/code-quality
# 25          https://www.github.com/topics/code-review
# 26             https://www.github.com/topics/compiler
# 27  https://www.github.com/topics/continuous-integ...
# 28             https://www.github.com/topics/covid-19
# 29                  https://www.github.com/topics/cpp

# %%
def scrape_topics_repos():
    print("Scraping list topics from Github")
    topics_df = scrape_topics()
    for index,row in topics_df.iterrows():
        print(f"Scraping top repositories for {row['title']}")
        scrape_topic(row['url'],row['title'])

# %%
scrape_topics_repos()
# Out:
# Scraping list topics from Github
# Scraping top repositories for 3D
# File 3D.csv already exists. Skipping...
# Scraping top repositories for Ajax
# File Ajax.csv already exists. Skipping...
# Scraping top repositories for Algorithm
# File Algorithm.csv already exists. Skipping...
# Scraping top repositories for Amp
# File Amp.csv already exists. Skipping...
# Scraping top repositories for Android
# File Android.csv already exists. Skipping...
# Scraping top repositories for Angular
# File Angular.csv already exists. Skipping...
# Scraping top repositories for Ansible
# File Ansible.csv already exists. Skipping...
# Scraping top repositories for API
# File API.csv already exists. Skipping...
# Scraping top repositories for Arduino
# File Arduino.csv already exists. Skipping...
# Scraping top repositories for ASP.NET
# File ASP.NET.csv already exists. Skipping...
# Scraping top repositories for Atom
# File Atom.csv already exists. Skipping...
# Scraping top repositories for Awesome Lists
# File Awesome Lists.csv already exists. Skipping...
# Scraping top repositories for Amazon Web Services
# File Amazon Web Services.csv already exists. Skipping...
# Scraping top repositories for Azure
# File Azure.csv already exists. Skipping...
# Scraping top repositories for Babel
# File Babel.csv already exists. Skipping...
# Scraping top repositories for Bash
# File Bash.csv already exists. Skipping...
# Scraping top repositories for Bitcoin
# File Bitcoin.csv already exists. Skipping...
# Scraping top repositories for Bootstrap
# File Bootstrap.csv already exists. Skipping...
# Scraping top repositories for Bot
# File Bot.csv already exists. Skipping...
# Scraping top repositories for C
# File C.csv already exists. Skipping...
# Scraping top repositories for Chrome
# File Chrome.csv already exists. Skipping...
# Scraping top repositories for Chrome extension
# Scraping top repositories for Command line interface
# Scraping top repositories for Clojure
# Scraping top repositories for Code quality
# Scraping top repositories for Code review
# Scraping top repositories for Compiler
# Scraping top repositories for Continuous integration
# Scraping top repositories for COVID-19
# Scraping top repositories for C++
